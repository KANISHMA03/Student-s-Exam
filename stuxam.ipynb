# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv('student_exam_data.csv(5.2.24).csv')
print(df.to_string())
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0              4                   82          0
# 1             10                   72          1
# 2              8                   59          0
# 3              6                   89          1
# 4              2                   81          0
# 5              2                   50          0
# 6              2                   95          0
# 7              9                   89          1
# 8              6                   97          1
# 9              7                   84          1
# 10             1                   77          0
# 11            10                   65          1
# 12             8                   96          1
# 13             3                   92          0
# 14             3                   43          0
# 15             3                   42          0
# 16             4                   63          0
# 17             6                   89          1
# ...

# %%
pd.options.display.float_format = '{:,.0f}'.format
print(df)
# Out:
#      Study Hours  Previous Exam Score  Pass/Fail
# 0              4                   82          0
# 1             10                   72          1
# 2              8                   59          0
# 3              6                   89          1
# 4              2                   81          0
# ..           ...                  ...        ...
# 495            4                   45          0
# 496            6                   95          1
# 497            2                   48          0
# 498           10                   97          1
# 499           10                   67          1
#
# [500 rows x 3 columns]

# %%
df.describe()
# Out:
#        Study Hours  Previous Exam Score  Pass/Fail
# count          500                  500        500
# mean             5                   69          0
# std              3                   17          0
# min              1                   40          0
# 25%              3                   54          0
# 50%              6                   68          0
# 75%              8                   84          1
# max             10                  100          1

# %%
X = df.drop(columns=['Pass/Fail'])
Y = df['Pass/Fail']
print(X.to_string())
print(Y.to_string())
# Out:
#      Study Hours  Previous Exam Score
# 0              4                   82
# 1             10                   72
# 2              8                   59
# 3              6                   89
# 4              2                   81
# 5              2                   50
# 6              2                   95
# 7              9                   89
# 8              6                   97
# 9              7                   84
# 10             1                   77
# 11            10                   65
# 12             8                   96
# 13             3                   92
# 14             3                   43
# 15             3                   42
# 16             4                   63
# 17             6                   89
# 18             5                   99
# 19             4                   49
# 20             7                   76
# 21             2                   63
# 22             4                   98
# 23             4                   91
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Study Hours          500 non-null    float64
#  1   Previous Exam Score  500 non-null    float64
#  2   Pass/Fail            500 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 11.8 KB
# None

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)
from sklearn.linear_model import LinearRegression
reg1 = LinearRegression()
reg1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg1.score(X_test,Y_test)
# Out:
# 0.5415173086461578

# %%
reg1.score(X_train,Y_train)
# Out:
# 0.5207877997852024

# %%
from sklearn.linear_model import Lasso
reg2 = Lasso(alpha=50,max_iter=100,tol=0.3)
reg2.fit(X_train,Y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.3)

# %%
reg2.score(X_train,Y_train)
# Out:
# 0.0

# %%
reg2.score(X_test,Y_test)
# Out:
# -0.18470418470418482

# %%
from sklearn.linear_model import Ridge
reg3 = Ridge(alpha=75,max_iter=100,tol=0.1)
reg3.fit(X_train,Y_train)
# Out:
# Ridge(alpha=75, max_iter=100, tol=0.1)

# %%
reg3.score(X_train,Y_train)
# Out:
# 0.5206233008015826

# %%
reg3.score(X_test,Y_test)
# Out:
# 0.5367867312663357

# %%
newdf = pd.crosstab(df['Study Hours'],df['Previous Exam Score'],df['Pass/Fail'].plot(kind='bar'))
print(newdf.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 newdf = pd.crosstab(df['Study Hours'],df['Previous Exam Score'],df['Pass/Fail'].plot(kind='bar'))
#       2 print(newdf.corr())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\pivot.py:688, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     685     raise ValueError("aggfunc cannot be used without values.")
#     687 if values is not None and aggfunc is None:
# --> 688     raise ValueError("values cannot be used without an aggfunc.")
#     690 if not is_nested_list_like(index):
#     691     index = [index]
#
# ValueError: values cannot be used without an aggfunc.

# %%
import plotly.express as px
df1 = px.data.iris()
fig = px.box(df1, x="sepal_width", y="sepal_length")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import plotly.express as px
#       2 df1 = px.data.iris()
#       3 fig = px.box(df1, x="sepal_width", y="sepal_length")
#
# ModuleNotFoundError: No module named 'plotly'

# %%
newdf = pd.crosstab(df['Study Hours'],df['Previous Exam Score'],df['Pass/Fail'].plot(kind='bar'))
print(newdf.corr())
